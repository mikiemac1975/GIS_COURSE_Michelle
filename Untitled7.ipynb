# %% [markdown]
# <a href="https://colab.research.google.com/github/mikiemac1975/GIS_COURSE_Michelle/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Welcome to your Python notebook##
# Firstly, we need to import the tools that you will need to allow Python to work with all the information from your files.
#
# Tool -
#
# <font color='blue'> Pandas </font>

# %%
import pandas as pd

# %% [markdown]
# Next, upload the dataset containing the information you will use to create your map. Give it a name - In this case, ours are called vetera and rottweil.
#
# By entering the command pd.read_csv , you are asking the notebook to read the file using the pandas tool you have just imported. As you can see from the URL, I have uploaded the datasets from my Github account.
#
# By adding the command .head() on the second line of this section of code, you are able to view the first few lines of the dataset in the notebook.

# %%
vetera = pd.read_csv('https://raw.githubusercontent.com/mikiemac1975/GIS_COURSE_Michelle/master/Vetera_REDUCED_25Jul2011.csv')
vetera.head()
# Out:
#   Site Name Cat_No  Trench  ...  Colour  Published illustration  Published references
# 0    Vetera  B0001  1267.0  ...     NaN                  Pl. 27                   NaN
# 1    Vetera  B0002   475.0  ...     NaN                  Pl. 27                   NaN
# 2    Vetera  B0003   982.0  ...     NaN                  Pl. 27                   NaN
# 3    Vetera  B0004    26.0  ...     NaN                  Pl. 27                   NaN
# 4    Vetera  B0005   327.1  ...     NaN                  Pl. 27                   NaN
#
# [5 rows x 37 columns]

# %%
vetera.dtypes
# Out:
# Site Name                    object
# Cat_No                       object
# Trench                      float64
# X coordinate                float64
# Y coordinate                float64
# Quantity                    float64
# Activity category            object
# act_cat                      object
# Material                     object
# Material detail original     object
# Type                         object
# Sub-type                     object
# Description                  object
# Inventory number             object
# Date                         object
# Period original              object
# Period                       object
# Camp                         object
# Building                     object
# Gender                       object
# Gender code                  object
# Height (cm)                  object
# Length (cm)                  object
# Rim diam. (cm)               object
# Base diam. (cm)              object
# Wall diam. (cm)              object
# Diam. (cm)                   object
# Width (cm)                   object
# Max. dim. (cm)               object
# Weight (g)                   object
# Surface                      object
# Fragment section             object
# Hardness                    float64
# Fabric                       object
# Colour                       object
# Published illustration       object
# Published references         object
# dtype: object

# %%
vetera.astype('object').fillna(0)
# Out:
#     Site Name Cat_No  ...  Published illustration            Published references
# 0      Vetera  B0001  ...                  Pl. 27                               0
# 1      Vetera  B0002  ...                  Pl. 27                               0
# 2      Vetera  B0003  ...                  Pl. 27                               0
# 3      Vetera  B0004  ...                  Pl. 27                               0
# 4      Vetera  B0005  ...                  Pl. 27                               0
# ..        ...    ...  ...                     ...                             ...
# 966    Vetera  K0009  ...                       0  Bonner Jahrb. 165, 1965: 275ff
# 967    Vetera  K0010  ...                       0  Bonner Jahrb. 165, 1965: 275ff
# 968    Vetera  K0011  ...                       0                               0
# 969    Vetera  K0020  ...                       0                               0
# 970    Vetera  K0021  ...                 Pl. 165                               0
#
# [971 rows x 37 columns]

# %% [markdown]
# We can import a few more tools here and have a go at plotting what we have...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# !pip install geopandas
import geopandas as gpd
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.6/dist-packages (0.6.2)
# Requirement already satisfied: fiona in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.8.13)
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.6.4.post2)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.25.3)
# Requirement already satisfied: pyproj in /usr/local/lib/python3.6/dist-packages (from geopandas) (2.4.2.post1)
# Requirement already satisfied: munch in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.12.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (0.5.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (19.3.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.17.4)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.6.1)

# %% [markdown]
# The data isnt very meaningful at the moment...
#
# Follow the same process as above to upload the next dataset.
#
# The URL for this is https://raw.githubusercontent.com/mikiemac1975/GIS_COURSE_Michelle/master/Rottweil_Reduced_28March2011.csv

# %%
# !pip install fiona
import requests
import fiona
import ipywidgets as widgets
# Out:
# Requirement already satisfied: fiona in /usr/local/lib/python3.6/dist-packages (1.8.13)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona) (1.12.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona) (19.3.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.6/dist-packages (from fiona) (2.5.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona) (7.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.6/dist-packages (from fiona) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.6/dist-packages (from fiona) (0.5.0)

# %%
rottweil = pd.read_csv('https://raw.githubusercontent.com/mikiemac1975/GIS_COURSE_Michelle/master/Rottweil_Reduced_28March2011.csv')
rottweil.head()
# Out:
#          Site name  ...                 Published parallels and references
# 0  Rottweil (AF V)  ...                                                NaN
# 1  Rottweil (AF V)  ...  Dominikanermuseum Rottweil. Lit.: Filtzinger, ...
# 2  Rottweil (AF V)  ...  Heiligmann, Alb-Limes pl.  89.20 (Gomadingen);...
# 3  Rottweil (AF V)  ...                                                NaN
# 4  Rottweil (AF V)  ...                                                NaN
#
# [5 rows x 36 columns]

# %%
rottweil.dtypes
# Out:
# Site name                              object
# Sort No.                              float64
# Original Cat. No.                      object
# Provenance code                         int64
# X coordinate                          float64
# Y coordinate                          float64
# No. artefacts                         float64
# Activity category                      object
# act_cat                                object
# Material                               object
# Material detail                        object
# Type                                   object
# Sub-type                               object
# Description                            object
# Inventory Number                       object
# Excavation area                        object
# Provenance 1                           object
# Provenance 2                           object
# Stratigraphical info                   object
# Other location information             object
# Date                                   object
# Period                                 object
# Fort building phase                    object
# Building phase reduced                 object
# Gender                                 object
# Gender code                            object
# Height (cm)                            object
# Length (cm)                            object
# Rim diam. (cm)                         object
# Max. diam. (cm)                        object
# Base diam. (cm)                       float64
# Breadth (cm)                           object
# Thickness (cm)                         object
# Weight (g)                            float64
# Published illustration                 object
# Published parallels and references     object
# dtype: object

# %%
rottweil.astype('object').fillna(0)
# Out:
#           Site name  ...                 Published parallels and references
# 0   Rottweil (AF V)  ...                                                  0
# 1   Rottweil (AF V)  ...  Dominikanermuseum Rottweil. Lit.: Filtzinger, ...
# 2   Rottweil (AF V)  ...  Heiligmann, Alb-Limes pl.  89.20 (Gomadingen);...
# 3   Rottweil (AF V)  ...                                                  0
# 4   Rottweil (AF V)  ...                                                  0
# 5   Rottweil (AF V)  ...  Riha, Fibeln pl. 36.971, 972; Riha, Neufunde p...
# 6   Rottweil (AF V)  ...                                                  0
# 7   Rottweil (AF V)  ...                                                  0
# 8   Rottweil (AF V)  ...                                                  0
# 9   Rottweil (AF V)  ...                                                  0
# 10  Rottweil (AF V)  ...                                                  0
# 11  Rottweil (AF V)  ...              Unz/Deschler-Erb, Katalog pl. 23.503.
# 12  Rottweil (AF V)  ...  Unz/Deschler-Erb, Katalog pl. 76,2360; W. H. M...
# 13  Rottweil (AF V)  ...                                                  0
# 14  Rottweil (AF V)  ...                                                  0
# 15  Rottweil (AF V)  ...                                                  0
# 16  Rottweil (AF V)  ...                                                  0
# 17  Rottweil (AF V)  ...                                                  0
# 18  Rottweil (AF V)  ...                                                  0
# 19  Rottweil (AF V)  ...  Lit.: A. Kaufmann-Heinimann, Götter- und Larar...
# 20  Rottweil (AF V)  ...                                                  0
# 21  Rottweil (AF V)  ...  Unz/Deschler-Erb, Katalog pl. 19.319-324; A. F...
# 22  Rottweil (AF V)  ...  Unz/Deschler-Erb, Katalog pl. 42f., no. 1081-1...
# 23  Rottweil (AF V)  ...                                                  0
# 24  Rottweil (AF V)  ...                                                  0
# 25  Rottweil (AF V)  ...  Unz/Deschler-Erb, Katalog pl. 62.1745-1747, 17...
# 26  Rottweil (AF V)  ...                                                  0
# 27  Rottweil (AF V)  ...                                                  0
# 28  Rottweil (AF V)  ...                          Riha, Schmuck pl. 12.208.
# 29  Rottweil (AF V)  ...                                                  0
# 30  Rottweil (AF V)  ...                                                  0
# 31  Rottweil (AF V)  ...                   Riha, Neufunde pl. 42.2839-2840.
# 32  Rottweil (AF V)  ...          Rütti, Gläser pl. 178-180, nos 4822-5053.
# 33  Rottweil (AF V)  ...                                                  0
# 34  Rottweil (AF V)  ...   Unz/Deschler-Erb, Katalog pl. 33f., no. 732-815.
# 35  Rottweil (AF V)  ...                          Riha, Fibeln pl. 62.1627.
# 36  Rottweil (AF V)  ...                                                  0
# 37  Rottweil (AF V)  ...                                                  0
# 38  Rottweil (AF V)  ...                                                  0
# 39  Rottweil (AF V)  ...                                                  0
# 40  Rottweil (AF V)  ...                                                  0
# 41  Rottweil (AF V)  ...                                                  0
# 42  Rottweil (AF V)  ...                                                  0
# 43  Rottweil (AF V)  ...  Riha, Fibeln pl. 30.813, 814; Riha, Neufunde p...
# 44  Rottweil (AF V)  ...                                                  0
# 45  Rottweil (AF V)  ...                                                  0
# 46  Rottweil (AF V)  ...                                                  0
# 47  Rottweil (AF V)  ...                                                  0
# 48  Rottweil (AF V)  ...                                                  0
# 49  Rottweil (AF V)  ...                                                  0
# 50  Rottweil (AF V)  ...                                                  0
# 51  Rottweil (AF V)  ...                                                  0
# 52  Rottweil (AF V)  ...                                                  0
# 53  Rottweil (AF V)  ...         Riha; Toilettgerät pl. 28-36, nos 264-389.
# 54  Rottweil (AF V)  ...             Bishop, Equipment 157, fig. 50, Typ Ic
# 55  Rottweil (AF V)  ...  Crummy, Colchester 65-67 Typ 2a with flattened...
# 56  Rottweil (AF V)  ...                                                  0
# 57  Rottweil (AF V)  ...                                                  0
# 58  Rottweil (AF V)  ...  Unz/Deschler-Erb, Katalog pl. 55,1503-1505; Bi...
#
# [59 rows x 36 columns]

# %%
from __future__ import division
# %pylab inline
# !pip install JSanimation
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Collecting JSanimation
#   Downloading https://files.pythonhosted.org/packages/3c/e6/a93a578400c38a43af8b4271334ed2444b42d65580f1d6721c9fe32e9fd8/JSAnimation-0.1.tar.gz
# Building wheels for collected packages: JSanimation
#   Building wheel for JSanimation (setup.py) ... done
#   Created wheel for JSanimation: filename=JSAnimation-0.1-cp36-none-any.whl size=11425 sha256=40a7ddc20642ad96f7d9172f0ace47cbc589c7f2d93b632e91116f6e17d2801c
#   Stored in directory: /root/.cache/pip/wheels/3c/c2/b2/b444dffc3eed9c78139288d301c4009a42c0dd061d3b62cead
# Successfully built JSanimation
# Installing collected packages: JSanimation
# Successfully installed JSanimation-0.1

# %%
data_vetera = array(child?,female,female?,female/child?,male?/female?)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-4e3412954960> in <module>()
# ----> 1 data_vetera = array('child?','female','female?','female/child?','male?/female?')
#
# ValueError: only 2 non-keyword arguments accepted
